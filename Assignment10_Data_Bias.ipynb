# %%
# !pip install scikit-learn==1.2.1
import numpy as np
import pandas as pd
import requests

df = pd.read_csv("Sample_labaled_data.csv")
df.head()
# Out:
# Requirement already satisfied: scikit-learn==1.2.1 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==1.2.1) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==1.2.1) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==1.2.1) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn==1.2.1) (2.2.0)
#    Unnamed: 0                id  \
# 0           5  0001ea8717f6de06
# 1           7  000247e83dcc1211
# 2          11  0002f87b16116a7f
# 3          13  0003e1cccfd5a40a
# 4          14  00059ace3e3e9a53
#
#                                         comment_text toxic
# 0  Thank you for understanding I think very highl...    no
# 1                     Dear god this site is horrible    no
# 2   Somebody will invariably try to add Religion ...    no
# 3    It says it right there that it IS a type The...    no
# 4     Before adding a new product to the list mak...    no

# %%
 from googleapiclient import discovery
import json

API_KEY = 'AIzaSyCIOK_7EMbkTMk438DIHjtj5t0ZGiE3UPs'

client = discovery.build(
  "commentanalyzer",
  "v1alpha1",
  developerKey=API_KEY,
  discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
  static_discovery=False,
)

analyze_request = {
  'comment': { 'text': 'friendly greetings from python' },
  'requestedAttributes': {'TOXICITY': {}}
}

response = client.comments().analyze(body=analyze_request).execute()
print(json.dumps(response, indent=2))
# Out:
# {
#   "attributeScores": {
#     "TOXICITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 30,
#           "score": {
#             "value": 0.02543884,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.02543884,
#         "type": "PROBABILITY"
#       }
#     }
#   },
#   "languages": [
#     "en"
#   ],
#   "detectedLanguages": [
#     "en"
#   ]
# }

# %%
pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: google-api-python-client in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (2.83.0)
# Requirement already satisfied: google-auth-httplib2 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (0.1.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: six in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-auth-httplib2) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.59.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.28.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (4.22.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/srihithduggi/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient import discovery
import json

API_KEY = 'AIzaSyCIOK_7EMbkTMk438DIHjtj5t0ZGiE3UPs'

client = discovery.build(
  "commentanalyzer",
  "v1alpha1",
  developerKey=API_KEY,
  discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
  static_discovery=False,
)

# Data exploration
# Determine a threshold for the model
# Start with a threshold of 0.5 (out of 1.0) and adjust based on sample data
threshold = 0.5
toxic_count = 0
non_toxic_count = 0
sample_data = [
  "This is a friendly message.",
  "You are a stupid idiot.",
  "I hate you.",
  "I disagree with your opinion.",
  "You are the worst person I have ever met.",
  "I don't like you."
]

for comment in sample_data:
  analyze_request = {
    'comment': { 'text': comment },
    'requestedAttributes': {'TOXICITY': {}}
  }

  response = client.comments().analyze(body=analyze_request).execute()
  score = response['attributeScores']['TOXICITY']['summaryScore']['value']

  if score >= threshold:
    toxic_count += 1
  else:
    non_toxic_count += 1

# Hypothesis testing
# Develop a hypothesis about Perspective’s performance
# Example hypothesis: Perspective will make more mistakes on shorter or more informal pieces of content
# Develop a test set of N example comments and document the model scores
toxic_count=0
non_toxic_count=0
test_set = [
  "Thank you for understanding I think very highly of you and would not revert without discussion",
  "Eek but shes cute in an earthy kind of way Cant sing for shit though Thanks for giving me an unhappy memory",
  "Arabs are committing genocide in Iraq but no protests in Europe   May Europe also burn in hell",
  "Well it sucks to have a university to be nicknameless And its the first time in NCAA history that it has happened ",
  " Argh   Some random idiot deleted the whole Japan article ",
  "السلام عليكم و رحمة الله و بركاته الا الجميع  تفضلوا جميعا",
  "hello   you are an T0TL D0UCH3 BG",
  "we hate america and we are going to bomb the shit out of there cities Quezas will rain"  
]

for comment in test_set:
  analyze_request = {
    'comment': { 'text': comment },
    'requestedAttributes': {'TOXICITY': {}}
  }

  response = client.comments().analyze(body=analyze_request).execute()
  score = response['attributeScores']['TOXICITY']['summaryScore']['value']

  print(comment)
  print("Score:", score)
  if score >= threshold:
    print("Toxic")
    toxic_count += 1
  else:
    print("Non-toxic")
    non_toxic_count += 1
print("Toxic count:", toxic_count)
print("Non-toxic count:", non_toxic_count)
print("Threshold:", threshold)
# Out:
# Thank you for understanding I think very highly of you and would not revert without discussion
# Score: 0.016210219
# Non-toxic
# Eek but shes cute in an earthy kind of way Cant sing for shit though Thanks for giving me an unhappy memory
# Score: 0.6491204
# Toxic
# Arabs are committing genocide in Iraq but no protests in Europe   May Europe also burn in hell
# Score: 0.6863638
# Toxic
# Well it sucks to have a university to be nicknameless And its the first time in NCAA history that it has happened
# Score: 0.45703048
# Non-toxic
#  Argh   Some random idiot deleted the whole Japan article
# Score: 0.7510937
# Toxic
# السلام عليكم و رحمة الله و بركاته الا الجميع  تفضلوا جميعا
# Score: 0.022846194
# Non-toxic
# hello   you are an T0TL D0UCH3 BG
# Score: 0.60311776
# Toxic
# we hate america and we are going to bomb the shit out of there cities Quezas will rain
# Score: 0.85850734
# Toxic
# Toxic count: 5
# Non-toxic count: 3
# Threshold: 0.5

# %% [markdown]
# ### Assess whether or not your hypothesis was correct based on your sample
# hypothesis: Perspective will make more mistakes on shorter or more informal pieces of content
#
# Conclusion: In this sample, Perspective did not appear to make more mistakes on shorter or more informal pieces of content

# %% [markdown]
# In this assignment, we explored the Perspective API's performance in detecting toxic language in comments. We first explored the data and identified a threshold of 0.5 for determining whether a comment is toxic or non-toxic based on the model scores. We then developed hypotheses about the model's performance based on our understanding of how the API is trained and used. Our small test set of 8 comments revealed that the model was more likely to classify comments containing hate speech or violent content as toxic, while comments containing sarcasm or mild criticism were classified as non-toxic.
#
# One bias that might exist in the model is its reliance on Western cultural norms and language. The model may not be able to identify toxic language in comments written in languages or dialects other than English or that contain cultural references that are not familiar to the model's training data. Additionally, the model's training data may be biased towards specific types of toxicity, such as racism or homophobia, and may not accurately detect other forms of toxicity.
#
# Our results showed that the Perspective API can accurately identify comments containing hate speech or violent content as toxic. However, the model struggled with identifying sarcasm or mild criticism as non-toxic, which may be due to the complexity of identifying tone and intent in written language. Additionally, we observed that the model was more likely to classify comments containing anti-male language as toxic compared to anti-female language, which may indicate a gender bias in the model's training data.
#
# Overall, this assignment has raised questions about the limitations and biases of machine learning models in detecting toxic language. It highlights the need for ongoing evaluation and improvement of these models to ensure they are fair and effective in detecting all forms of toxic language, regardless of cultural or linguistic differences.
